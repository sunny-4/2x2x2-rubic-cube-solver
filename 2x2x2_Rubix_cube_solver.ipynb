# %%
import time
from collections import deque

# Solved permutation string
SOLVED_PERM = "ggggwwwwrrrrbbbbyyyyoooo"

# Notations
NOTATIONS = ["F ", "F2", "F'", "U ", "U2", "U'", "R ", "R2", "R'"]

def split_faces(perm):
    return {
        "F": perm[0:4],
        "U": perm[4:8],
        "R": perm[8:12],
        "B": perm[12:16],
        "D": perm[16:20],
        "L": perm[20:24],
    }

def print_cube(perm):
    faces = split_faces(perm)
    print("    ", faces["U"][0], faces["U"][1])
    print("    ", faces["U"][2], faces["U"][3])
    print(faces["L"][0], faces["L"][1], faces["F"][0], faces["F"][1], faces["R"][0], faces["R"][1], faces["B"][0], faces["B"][1])
    print(faces["L"][2], faces["L"][3], faces["F"][2], faces["F"][3], faces["R"][2], faces["R"][3], faces["B"][2], faces["B"][3])
    print("    ", faces["D"][0], faces["D"][1])
    print("    ", faces["D"][2], faces["D"][3])
    print()

def produce_permutation(notation, perm):
    # Decompose perm into individual stickers
    f1,f2,f3,f4,u1,u2,u3,u4,r1,r2,r3,r4,b1,b2,b3,b4,d1,d2,d3,d4,l1,l2,l3,l4 = perm

    if notation == "F ":
        perm = f3+f1+f4+f2+u1+u2+l4+l2+u3+r2+u4+r4+b1+b2+b3+b4+r3+r1+d3+d4+l1+d1+l3+d2
    elif notation == "F2":
        perm = f4+f3+f2+f1+u1+u2+d2+d1+l4+r2+l2+r4+b1+b2+b3+b4+u4+u3+d3+d4+l1+r3+l3+r1
    elif notation == "F'":
        perm = f2+f4+f1+f3+u1+u2+r1+r3+d2+r2+d1+r4+b1+b2+b3+b4+l2+l4+d3+d4+l1+u4+l3+u3
    elif notation == "U ":
        perm = r1+r2+f3+f4+u3+u1+u4+u2+b1+b2+r3+r4+l1+l2+b3+b4+d1+d2+d3+d4+f1+f2+l3+l4
    elif notation == "U2":
        perm = b1+b2+f3+f4+u4+u3+u2+u1+l1+l2+r3+r4+f1+f2+b3+b4+d1+d2+d3+d4+r1+r2+l3+l4
    elif notation == "U'":
        perm = l1+l2+f3+f4+u2+u4+u1+u3+f1+f2+r3+r4+r1+r2+b3+b4+d1+d2+d3+d4+b1+b2+l3+l4
    elif notation == "R ":
        perm = f1+d2+f3+d4+u1+f2+u3+f4+r3+r1+r4+r2+u4+b2+u2+b4+d1+b3+d3+b1+l1+l2+l3+l4
    elif notation == "R2":
        perm = f1+b3+f3+b1+u1+d2+u3+d4+r4+r3+r2+r1+f4+b2+f2+b4+d1+u2+d3+u4+l1+l2+l3+l4
    elif notation == "R'":
        perm = f1+u2+f3+u4+u1+b3+u3+b1+r2+r4+r1+r3+d4+b2+d2+b4+d1+f2+d3+f4+l1+l2+l3+l4
    else:
        # Do nothing for unsupported moves
        perm = perm
    return perm

def is_solved(perm):
    for i in range(0, 24, 4):
        if perm[i:i+4] != perm[i] * 4:
            return False
    return True

def bfs_solver(start_perm):
    visited = set()
    queue = deque()
    queue.append(("", start_perm))

    while queue:
        path, perm = queue.popleft()

        print(f"Move sequence so far: {path}")
        print_cube(perm)
        time.sleep(0.1)

        if is_solved(perm):
            print("Cube solved!")
            return path

        for notation in NOTATIONS:
            if len(path) >= 2 and path[-2] == notation[0]:
                continue

            new_perm = produce_permutation(notation, perm)
            if new_perm not in visited:
                visited.add(new_perm)
                queue.append((path + notation, new_perm))

    print("No solution found!")
    return None

# ---------------------------
# Example scramble
scrambled_perm = SOLVED_PERM
scrambled_perm = produce_permutation("F ", scrambled_perm)
scrambled_perm = produce_permutation("U ", scrambled_perm)
scrambled_perm = produce_permutation("R ", scrambled_perm)

print("Scrambled state:")
print_cube(scrambled_perm)

start_time = time.time()        # Start timing

solution_path = bfs_solver(scrambled_perm)

end_time = time.time()          # End timing

if solution_path:
    print("Final solution path:", solution_path)
    print("Number of moves:", len(solution_path) // 2)
    print(f"Time taken: {end_time - start_time:.2f} seconds")
else:
    print("No solution found!")
# Out:
# Scrambled state:
#      o r
#      o g
# g g w r w b w y
# o y g y r b w b
#      r b
#      y o
#
# Move sequence so far:
#      o r
#      o g
# g g w r w b w y
# o y g y r b w b
#      r b
#      y o
#
# Move sequence so far: F
#      o r
#      y g
# g r g w o b w y
# o b y r g b w b
#      r w
#      y o
#
# Move sequence so far: F2
#      o r
#      b r
# g r y g y b w y
# o w r w g b w b
#      g o
#      y o
#
# Move sequence so far: F'
#      o r
#      w r
# g g r y b b w y
# o o w g r b w b
#      g y
#      y o
#
# Move sequence so far: U
#      o o
#      g r
# w r w b w y g g
# o y g y r b w b
#      r b
#      y o
#
# Move sequence so far: U2
#      g o
#      r o
# w b w y g g w r
# o y g y r b w b
#      r b
#      y o
#
# Move sequence so far: U'
#      r g
#      o o
# w y g g w r w b
# o y g y r b w b
#      r b
#      y o
#
# Move sequence so far: R
#      o r
#      o y
# g g w b r w g y
# o y g o b b r b
#      r w
#      y w
#
# Move sequence so far: R2
#      o b
#      o o
# g g w w b r y y
# o y g w b w r b
#      r r
#      y g
#
# Move sequence so far: R'
#      o w
#      o w
# g g w r b b o y
# o y g g w r b b
#      r r
#      y y
#
# Move sequence so far: F U
#      y o
#      g r
# g w o b w y g r
# o b y r g b w b
#      r w
#      y o
#
# Move sequence so far: F U2
#      g y
#      r o
# o b w y g r g w
# o b y r g b w b
#      r w
#      y o
#
# Move sequence so far: F U'
#      r g
#      o y
# w y g r g w o b
# o b y r g b w b
#      r w
#      y o
#
# Move sequence so far: F R
#      o w
#      y r
# g r g w g o g y
# o b y o b b r b
#      r w
#      y w
#
# Move sequence so far: F R2
#      o w
#      y o
# g r g w b g r y
# o b y w b o w b
#      r r
#      y g
#
# Move sequence so far: F R'
#      o w
#      y w
# g r g r b b o y
# o b y g o g w b
#      r w
#      y r
#
# Move sequence so far: F2U
#      b o
#      r r
# y g y b w y g r
# o w r w g b w b
#      g o
#      y o
#
# Move sequence so far: F2U2
#      r b
#      r o
# y b w y g r y g
# o w r w g b w b
#      g o
#      y o
#
# Move sequence so far: F2U'
#      r r
#      o b
# w y g r y g y b
# o w r w g b w b
#      g o
#      y o
#
# Move sequence so far: F2R
#      o g
#      b w
# g r y o g y r y
# o w r o b b r b
#      g w
#      y w
#
# Move sequence so far: F2R2
#      o o
#      b o
# g r y w b g w y
# o w r w b y g b
#      g r
#      y r
#
# Move sequence so far: F2R'
#      o w
#      b w
# g r y r b b o y
# o w r r y g o b
#      g g
#      y w
#
# Move sequence so far: F'U
#      w o
#      r r
# r y b b w y g g
# o o w g r b w b
#      g y
#      y o
#
# Move sequence so far: F'U2
#      r w
#      r o
# b b w y g g r y
# o o w g r b w b
#      g y
#      y o
#
# Move sequence so far: F'U'
#      r r
#      o w
# w y g g r y b b
# o o w g r b w b
#      g y
#      y o
#
# Move sequence so far: F'R
#      o y
#      w g
# g g r y r b r y
# o o w o b b r b
#      g w
#      y w
#
# Move sequence so far: F'R2
#      o y
#      w o
# g g r w b r g y
# o o w w b b y b
#      g r
#      y r
#
# Move sequence so far: F'R'
#      o w
#      w w
# g g r r b b o y
# o o w r b r y b
#      g y
#      y g
#
# Move sequence so far: U F
#      o o
#      y r
# w r g w g y g g
# o b y b r b w b
#      r w
#      y o
#
# Move sequence so far: U F2
#      o o
#      b r
# w r y g y y g g
# o w b w r b w b
#      r g
#      y o
#
# Move sequence so far: U F'
#      o o
#      w r
# w r b y b y g g
# o g w g r b w b
#      r y
#      y o
#
# Move sequence so far: U R
#      o b
#      g y
# w r w b r w r g
# o y g o b y o b
#      r w
#      y g
#
# Move sequence so far: U R2
#      o b
#      g o
# w r w w b r y g
# o y g g y w b b
#      r o
#      y r
#
# Move sequence so far: U R'
#      o w
#      g g
# w r w o y b o g
# o y g r w r b b
#      r b
#      y y
#
# Move sequence so far: U2F
#      g o
#      y b
# w r g w r g w r
# o b y y o b w b
#      r g
#      y o
#
# Move sequence so far: U2F2
#      g o
#      b r
# w r y g y g w r
# o g y w b b w b
#      o r
#      y o
#
# Move sequence so far: U2F'
#      g o
#      g r
# w o y y b g w r
# o r w g r b w b
#      b y
#      y o
#
# Move sequence so far: U2R
#      g y
#      r y
# w b w b r g o r
# o y g o b g o b
#      r w
#      y w
#
# Move sequence so far: U2R2
#      g b
#      r o
# w b w w b r y r
# o y g w g g y b
#      r o
#      y o
#
# Move sequence so far: U2R'
#      g w
#      r w
# w b w o g b o r
# o y g o g r b b
#      r y
#      y y
#
# Move sequence so far: U'F
#      r g
#      y y
# w r g g o r w b
# o b y g o b w b
#      r w
#      y o
#
# Move sequence so far: U'F2
#      r g
#      b r
# w r y g y r w b
# o w g g y b w b
#      o o
#      y o
#
# Move sequence so far: U'F'
#      r g
#      w r
# w o g y b r w b
# o o g g r b w b
#      y y
#      y o
#
# Move sequence so far: U'R
#      r g
#      o y
# w y g b r w o b
# o y g o b r g b
#      r w
#      y w
#
# Move sequence so far: U'R2
#      r b
#      o o
# w y g w b r y b
# o y g w r w g b
#      r g
#      y o
#
# Move sequence so far: U'R'
#      r w
#      o w
# w y g g r b o b
# o y g o w r b b
#      r g
#      y y
#
# Move sequence so far: R F
#      o r
#      y g
# g r g w o w g y
# o w o b y b r b
#      b r
#      y w
#
# Move sequence so far: R F2
#      o r
#      w r
# g b o g y w g y
# o r b w g b r b
#      y o
#      y w
#
# Move sequence so far: R F'
#      o r
#      r b
# g y b o w w g y
# o o w g r b r b
#      g y
#      y w
#
# Move sequence so far: R U
#      o o
#      y r
# w b r w g y g g
# o y g o b b r b
#      r w
#      y w
#
# Move sequence so far: R U2
#      y o
#      r o
# r w g y g g w b
# o y g o b b r b
#      r w
#      y w
#
# Move sequence so far: R U'
#      r y
#      o o
# g y g g w b r w
# o y g o b b r b
#      r w
#      y w
#
# Move sequence so far: R2F
#      o b
#      y g
# g r g w o r y y
# o r w w o w r b
#      b b
#      y g
#
# Move sequence so far: R2F2
#      o b
#      r r
# g b w g y r y y
# o b w w g w r b
#      o o
#      y g
#
# Move sequence so far: R2F'
#      o b
#      b b
# g o w w r r y y
# o o w g r w r b
#      g y
#      y g
#
# Move sequence so far: R2U
#      o o
#      o b
# w w b r y y g g
# o y g w b w r b
#      r r
#      y g
#
# Move sequence so far: R2U2
#      o o
#      b o
# b r y y g g w w
# o y g w b w r b
#      r r
#      y g
#
# Move sequence so far: R2U'
#      b o
#      o o
# y y g g w w b r
# o y g w b w r b
#      r r
#      y g
#
# Move sequence so far: R'F
#      o w
#      y g
# g r g w o b o y
# o r g r w r b b
#      w b
#      y y
#
# Move sequence so far: R'F2
#      o w
#      r r
# g w g g y b o y
# o b r w g r b b
#      w o
#      y y
#
# Move sequence so far: R'F'
#      o w
#      b w
# g w r g r b o y
# o o w g r r b b
#      g y
#      y y
#
# Move sequence so far: R'U
#      o o
#      w w
# w r b b o y g g
# o y g g w r b b
#      r r
#      y y
#
# Move sequence so far: R'U2
#      w o
#      w o
# b b o y g g w r
# o y g g w r b b
#      r r
#      y y
#
# Move sequence so far: R'U'
#      w w
#      o o
# o y g g w r b b
# o y g g w r b b
#      r r
#      y y
#
# Move sequence so far: F U F
#      y o
#      b w
# g r y o g y g r
# o w r b r b w b
#      g w
#      y o
#
# Move sequence so far: F U F2
#      y o
#      w r
# g g r y b y g r
# o w b o w b w b
#      r g
#      y o
#
# Move sequence so far: F U F'
#      y o
#      w g
# g r b r w y g r
# o g o y r b w b
#      w b
#      y o
#
# Move sequence so far: F U R
#      y b
#      g r
# g w o w g w r r
# o b y o b y o b
#      r w
#      y g
#
# Move sequence so far: F U R2
#      y w
#      g o
# g w o w b g r r
# o b y g y w b b
#      r o
#      y r
#
# Move sequence so far: F U R'
#      y w
#      g g
# g w o o y b o r
# o b y r w g w b
#      r b
#      y r
#
# Move sequence so far: F U2F
#      g y
#      b b
# o r y w r r g w
# o w r y o b w b
#      g g
#      y o
#
# Move sequence so far: F U2F2
#      g y
#      w r
# o g r y b r g w
# o g y w b b w b
#      o r
#      y o
#
# Move sequence so far: F U2F'
#      g y
#      g g
# o o y r w r g w
# o r w y r b w b
#      b b
#      y o
#
# Move sequence so far: F U2R
#      g y
#      r r
# o b w w g g o w
# o b y o b r y b
#      r w
#      y g
#
# Move sequence so far: F U2R2
#      g w
#      r o
# o b w w b g r w
# o b y g r g y b
#      r y
#      y o
#
# Move sequence so far: F U2R'
#      g w
#      r g
# o b w y r b o w
# o b y o g g w b
#      r y
#      y r
#
# Move sequence so far: F U'F
#      r g
#      b y
# w r y g o w o b
# o w r r y b w b
#      g g
#      y o
#
# Move sequence so far: F U'F2
#      r g
#      w r
# w g r y b w o b
# o g r g y b w b
#      y o
#      y o
#
# Move sequence so far: F U'F'
#      r g
#      g g
# w y r r w w o b
# o o g y r b w b
#      y b
#      y o
#
# Move sequence so far: F U'R
#      r r
#      o r
# w y g w g g y b
# o b y o b w g b
#      r w
#      y o
#
# Move sequence so far: F U'R2
#      r w
#      o o
# w y g w b g r b
# o b y o w g r b
#      r g
#      y y
#
# Move sequence so far: F U'R'
#      r w
#      o o
# w y g g w b o b
# o b y y g g w b
#      r r
#      y r
#
# Move sequence so far: F R F
#      o w
#      b r
# g r y g y o g y
# o w o w r b r b
#      b g
#      y w
#
# Move sequence so far: F R F2
#      o w
#      w r
# g b o y b o g y
# o g w g r b r b
#      r y
#      y w
#
# Move sequence so far: F R F'
#      o w
#      g b
# g r w o w o g y
# o y g y r b r b
#      r b
#      y w
#
# Move sequence so far: F R U
#      y o
#      r w
# g w g o g y g r
# o b y o b b r b
#      r w
#      y w
#
# Move sequence so far: F R U2
#      r y
#      w o
# g o g y g r g w
# o b y o b b r b
#      r w
#      y w
#
# Move sequence so far: F R U'
#      w r
#      o y
# g y g r g w g o
# o b y o b b r b
#      r w
#      y w
#
# Move sequence so far: F R2F
#      o w
#      b r
# g r y g y g r y
# o r w w o o w b
#      b b
#      y g
#
# Move sequence so far: F R2F2
#      o w
#      r r
# g b w y b g r y
# o b w g r o w b
#      o y
#      y g
#
# Move sequence so far: F R2F'
#      o w
#      b b
# g o w w r g r y
# o y g y r o w b
#      r b
#      y g
#
# Move sequence so far: F R2U
#      y o
#      o w
# g w b g r y g r
# o b y w b o w b
#      r r
#      y g
#
# Move sequence so far: F R2U2
#      o y
#      w o
# b g r y g r g w
# o b y w b o w b
#      r r
#      y g
#
# Move sequence so far: F R2U'
#      w o
#      o y
# r y g r g w b g
# o b y w b o w b
#      r r
#      y g
#
# Move sequence so far: F R'F
#      o w
#      b r
# g r y g y b o y
# o w g r w g w b
#      o b
#      y r
#
# Move sequence so far: F R'F2
#      o w
#      w r
# g o g y b b o y
# o b r g r g w b
#      w y
#      y r
#
# Move sequence so far: F R'F'
#      o w
#      b o
# g w r g w b o y
# o y g y r g w b
#      r b
#      y r
#
# Move sequence so far: F R'U
#      y o
#      w w
# g r b b o y g r
# o b y g o g w b
#      r w
#      y r
#
# Move sequence so far: F R'U2
#      w y
#      w o
# b b o y g r g r
# o b y g o g w b
#      r w
#      y r
#
# Move sequence so far: F R'U'
#      w w
#      o y
# o y g r g r b b
# o b y g o g w b
#      r w
#      y r
#
# Move sequence so far: F2U F
#      b o
#      w g
# y g r y r y g r
# o o w b r b w b
#      g w
#      y o
#
# Move sequence so far: F2U F2
#      b o
#      o g
# y g w r w y g r
# o w b y g b w b
#      r r
#      y o
#
# Move sequence so far: F2U F'
#      b o
#      w g
# y r b w o y g r
# o r y r g b w b
#      g w
#      y o
#
# Move sequence so far: F2U R
#      b b
#      r w
# y g y o g w r r
# o w r o b y o b
#      g w
#      y g
#
# Move sequence so far: F2U R2
#      b o
#      r o
# y g y w b g w r
# o w r g y w b b
#      g o
#      y r
#
# Move sequence so far: F2U R'
#      b w
#      r g
# y g y o y b o r
# o w r r w g o b
#      g b
#      y w
#
# Move sequence so far: F2U2F
#      r b
#      w b
# y g r w r r y g
# o o w y o b w b
#      g g
#      y o
#
# Move sequence so far: F2U2F2
#      r b
#      o g
# y g w r w r y g
# o g y w b b w b
#      o r
#      y o
#
# Move sequence so far: F2U2F'
#      r b
#      g g
# y o y w o r y g
# o r w r g b w b
#      b w
#      y o
#
# Move sequence so far: F2U2R
#      r y
#      r w
# y b w o g g o g
# o w r o b r b b
#      g w
#      y y
#
# Move sequence so far: F2U2R2
#      r o
#      r o
# y b w w b g w g
# o w r y r g y b
#      g b
#      y o
#
# Move sequence so far: F2U2R'
#      r w
#      r y
# y b w b r b o g
# o w r o g g o b
#      g y
#      y w
#
# Move sequence so far: F2U'F
#      r r
#      w y
# w g r g o g y b
# o o w r b b w b
#      g y
#      y o
#
# Move sequence so far: F2U'F2
#      r r
#      o g
# w g w r w g y b
# o y r g y b w b
#      b o
#      y o
#
# Move sequence so far: F2U'F'
#      r r
#      y g
# w b r w o g y b
# o o g r g b w b
#      y w
#      y o
#
# Move sequence so far: F2U'R
#      r r
#      o w
# w y g o g y b b
# o w r o b g r b
#      g w
#      y y
#
# Move sequence so far: F2U'R2
#      r o
#      o o
# w y g w b g w b
# o w r y g y r b
#      g r
#      y b
#
# Move sequence so far: F2U'R'
#      r w
#      o y
# w y g r g b o b
# o w r b y g o b
#      g r
#      y w
#
# Move sequence so far: F2R F
#      o g
#      w r
# g g r y b y r y
# o w o o w b r b
#      b g
#      y w
#
# Move sequence so far: F2R F2
#      o g
#      w g
# g b o r w y r y
# o g o y r b r b
#      w b
#      y w
#
# Move sequence so far: F2R F'
#      o g
#      g b
# g w o o w y r y
# o b y r g b r b
#      r w
#      y w
#
# Move sequence so far: F2R U
#      b o
#      w g
# y o g y r y g r
# o w r o b b r b
#      g w
#      y w
#
# Move sequence so far: F2R U2
#      w b
#      g o
# g y r y g r y o
# o w r o b b r b
#      g w
#      y w
#
# Move sequence so far: F2R U'
#      g w
#      o b
# r y g r y o g y
# o w r o b b r b
#      g w
#      y w
#
# Move sequence so far: F2R2F
#      o o
#      w r
# g g r y b g w y
# o r w w o y g b
#      b b
#      y r
#
# Move sequence so far: F2R2F2
#      o o
#      r g
# g b w r w g w y
# o b w y r y g b
#      o b
#      y r
#
# Move sequence so far: F2R2F'
#      o o
#      b b
# g o w w r g w y
# o b y r g y g b
#      r w
#      y r
#
# Move sequence so far: F2R2U
#      b o
#      o o
# y w b g w y g r
# o w r w b y g b
#      g r
#      y r
#
# Move sequence so far: F2R2U2
#      o b
#      o o
# b g w y g r y w
# o w r w b y g b
#      g r
#      y r
#
# Move sequence so far: F2R2U'
#      o o
#      o b
# w y g r y w b g
# o w r w b y g b
#      g r
#      y r
#
# Move sequence so far: F2R'F
#      o w
#      w r
# g g r y b b o y
# o g r r w g o b
#      y b
#      y w
#
# Move sequence so far: F2R'F2
#      o w
#      g g
# g y r r w b o y
# o b r y r g o b
#      w b
#      y w
#
# Move sequence so far: F2R'F'
#      o w
#      b y
# g w r r g b o y
# o b y r g g o b
#      r w
#      y w
#
# Move sequence so far: F2R'U
#      b o
#      w w
# y r b b o y g r
# o w r r y g o b
#      g g
#      y w
#
# Move sequence so far: F2R'U2
#      w b
#      w o
# b b o y g r y r
# o w r r y g o b
#      g g
#      y w
#
# Move sequence so far: F2R'U'
#      w w
#      o b
# o y g r y r b b
# o w r r y g o b
#      g g
#      y w
#
# Move sequence so far: F'U F
#      w o
#      o y
# r g w b r y g g
# o y g b r b w b
#      r w
#      y o
#
# Move sequence so far: F'U F2
#      w o
#      y g
# r r g w o y g g
# o w b b y b w b
#      r r
#      y o
#
# Move sequence so far: F'U F'
#      w o
#      w r
# r r b g y y g g
# o r b w g b w b
#      y o
#      y o
#
# Move sequence so far: F'U R
#      w b
#      r g
# r y b y r w r g
# o o w o b y o b
#      g w
#      y g
#
# Move sequence so far: F'U R2
#      w y
#      r o
# r y b w b r g g
# o o w g y w b b
#      g o
#      y r
#
# Move sequence so far: F'U R'
#      w w
#      r g
# r y b o y b o g
# o o w r w r y b
#      g b
#      y g
#
# Move sequence so far: F'U2F
#      r w
#      o b
# b g w w r g r y
# o y g y o b w b
#      r g
#      y o
#
# Move sequence so far: F'U2F2
#      r w
#      y g
# b r g w o g r y
# o g y w b b w b
#      o r
#      y o
#
# Move sequence so far: F'U2F'
#      r w
#      g r
# b o y g y g r y
# o r w w g b w b
#      b o
#      y o
#
# Move sequence so far: F'U2R
#      r y
#      r g
# b b w y r g o y
# o o w o b g w b
#      g w
#      y r
#
# Move sequence so far: F'U2R2
#      r y
#      r o
# b b w w b r g y
# o o w r g g y b
#      g w
#      y o
#
# Move sequence so far: F'U2R'
#      r w
#      r r
# b b w w g b o y
# o o w o g r y b
#      g y
#      y g
#
# Move sequence so far: F'U'F
#      r r
#      o y
# w g w g o y b b
# o y g g w b w b
#      r r
#      y o
#
# Move sequence so far: F'U'F2
#      r r
#      y g
# w r g w o y b b
# o r g g y b w b
#      w o
#      y o
#
# Move sequence so far: F'U'F'
#      r r
#      r r
# w w g g y y b b
# o o g w g b w b
#      y o
#      y o
#
# Move sequence so far: F'U'R
#      r g
#      o g
# w y g y r r w b
# o o w o b y r b
#      g w
#      y b
#
# Move sequence so far: F'U'R2
#      r y
#      o o
# w y g w b r g b
# o o w b y r g b
#      g r
#      y w
#
# Move sequence so far: F'U'R'
#      r w
#      o b
# w y g r y b o b
# o o w w r r y b
#      g g
#      y g
#
# Move sequence so far: F'R F
#      o y
#      o g
# g g w r w b r y
# o w o y g b r b
#      b r
#      y w
#
# Move sequence so far: F'R F2
#      o y
#      w g
# g b o w o b r y
# o r y r g b r b
#      g w
#      y w
#
# Move sequence so far: F'R F'
#      o y
#      r b
# g g y o w b r y
# o w r w g b r b
#      g o
#      y w
#
# Move sequence so far: F'R U
#      w o
#      g y
# r y r b r y g g
# o o w o b b r b
#      g w
#      y w
#
# Move sequence so far: F'R U2
#      g w
#      y o
# r b r y g g r y
# o o w o b b r b
#      g w
#      y w
#
# Move sequence so far: F'R U'
#      y g
#      o w
# r y g g r y r b
# o o w o b b r b
#      g w
#      y w
#
# Move sequence so far: F'R2F
#      o y
#      o g
# g g w r w r g y
# o r w w o b y b
#      b b
#      y r
#
# Move sequence so far: F'R2F2
#      o y
#      r g
# g b w w o r g y
# o b w r g b y b
#      o w
#      y r
#
# Move sequence so far: F'R2F'
#      o y
#      b b
# g o w w r r g y
# o w r w g b y b
#      g o
#      y r
#
# Move sequence so far: F'R2U
#      w o
#      o y
# r w b r g y g g
# o o w w b b y b
#      g r
#      y r
#
# Move sequence so far: F'R2U2
#      o w
#      y o
# b r g y g g r w
# o o w w b b y b
#      g r
#      y r
#
# Move sequence so far: F'R2U'
#      y o
#      o w
# g y g g r w b r
# o o w w b b y b
#      g r
#      y r
#
# Move sequence so far: F'R'F
#      o w
#      o g
# g g w r w b o y
# o y r r w r y b
#      b b
#      y g
#
# Move sequence so far: F'R'F2
#      o w
#      y g
# g b r w o b o y
# o b r r g r y b
#      w w
#      y g
#
# Move sequence so far: F'R'F'
#      o w
#      b b
# g w r r y b o y
# o w r w g r y b
#      g o
#      y g
#
# Move sequence so far: F'R'U
#      w o
#      w w
# r r b b o y g g
# o o w r b r y b
#      g y
#      y g
#
# Move sequence so far: F'R'U2
#      w w
#      w o
# b b o y g g r r
# o o w r b r y b
#      g y
#      y g
#
# Move sequence so far: F'R'U'
#      w w
#      o w
# o y g g r r b b
# o o w r b r y b
#      g y
#      y g
#
# Move sequence so far: U F U
#      y o
#      r o
# g w g y g g w r
# o b y b r b w b
#      r w
#      y o
#
# Move sequence so far: U F U2
#      r y
#      o o
# g y g g w r g w
# o b y b r b w b
#      r w
#      y o
#
# Move sequence so far: U F U'
#      o r
#      o y
# g g w r g w g y
# o b y b r b w b
#      r w
#      y o
#
# Move sequence so far: U F R
#      o w
#      y b
# w r g w r g r g
# o b y o b y o b
#      r w
#      y g
#
# Move sequence so far: U F R2
#      o w
#      y o
# w r g w b r b g
# o b y g y g w b
#      r o
#      y r
#
# Move sequence so far: U F R'
#      o w
#      y g
# w r g o y b o g
# o b y r g r w b
#      r w
#      y b
#
# Move sequence so far: U F2U
#      b o
#      r o
# y g y y g g w r
# o w b w r b w b
#      r g
#      y o
#
# Move sequence so far: U F2U2
#      r b
#      o o
# y y g g w r y g
# o w b w r b w b
#      r g
#      y o
#
# Move sequence so far: U F2U'
#      o r
#      o b
# g g w r y g y y
# o w b w r b w b
#      r g
#      y o
#
# Move sequence so far: U F2R
#      o g
#      b w
# w r y g r y r g
# o w b o b y o b
#      r w
#      y g
#
# Move sequence so far: U F2R2
#      o g
#      b o
# w r y w b r w g
# o w b g y y g b
#      r o
#      y r
#
# Move sequence so far: U F2R'
#      o w
#      b g
# w r y o y b o g
# o w b r y r g b
#      r g
#      y w
#
# Move sequence so far: U F'U
#      w o
#      r o
# b y b y g g w r
# o g w g r b w b
#      r y
#      y o
#
# Move sequence so far: U F'U2
#      r w
#      o o
# b y g g w r b y
# o g w g r b w b
#      r y
#      y o
#
# Move sequence so far: U F'U'
#      o r
#      o w
# g g w r b y b y
# o g w g r b w b
#      r y
#      y o
#
# Move sequence so far: U F'R
#      o y
#      w g
# w r b y r b r g
# o g w o b y o b
#      r w
#      y g
#
# Move sequence so far: U F'R2
#      o y
#      w o
# w r b w b r g g
# o g w g y b y b
#      r o
#      y r
#
# Move sequence so far: U F'R'
#      o w
#      w g
# w r b o y b o g
# o g w r b r y b
#      r y
#      y g
#
# Move sequence so far: U R F
#      o b
#      y r
# w r g w g w r g
# o w o b y y o b
#      b r
#      y g
#
# Move sequence so far: U R F2
#      o b
#      w r
# w b o g y w r g
# o r b w r y o b
#      y g
#      y g
#
# Move sequence so far: U R F'
#      o b
#      r b
# w y b o w w r g
# o g w g r y o b
#      r y
#      y g
#
# Move sequence so far: U R U
#      g o
#      y b
# w b r w r g w r
# o y g o b y o b
#      r w
#      y g
#
# Move sequence so far: U R U2
#      y g
#      b o
# r w r g w r w b
# o y g o b y o b
#      r w
#      y g
#
# Move sequence so far: U R U'
#      b y
#      o g
# r g w r w b r w
# o y g o b y o b
#      r w
#      y g
#
# Move sequence so far: U R2F
#      o b
#      y r
# w r g w g r y g
# o o g w o w b b
#      y b
#      y r
#
# Move sequence so far: U R2F2
#      o b
#      o r
# w y g g y r y g
# o b w w r w b b
#      o g
#      y r
#
# Move sequence so far: U R2F'
#      o b
#      b y
# w o w g o r y g
# o g w g r w b b
#      r y
#      y r
#
# Move sequence so far: U R2U
#      g o
#      o b
# w w b r y g w r
# o y g g y w b b
#      r o
#      y r
#
# Move sequence so far: U R2U2
#      o g
#      b o
# b r y g w r w w
# o y g g y w b b
#      r o
#      y r
#
# Move sequence so far: U R2U'
#      b o
#      o g
# y g w r w w b r
# o y g g y w b b
#      r o
#      y r
#
# Move sequence so far: U R'F
#      o w
#      y r
# w r g w g b o g
# o b r o g r b b
#      w y
#      y y
#
# Move sequence so far: U R'F2
#      o w
#      b r
# w w r g y b o g
# o y o w r r b b
#      g g
#      y y
#
# Move sequence so far: U R'F'
#      o w
#      y w
# w g o r b b o g
# o g w g r r b b
#      r y
#      y y
#
# Move sequence so far: U R'U
#      g o
#      g w
# w o y b o g w r
# o y g r w r b b
#      r b
#      y y
#
# Move sequence so far: U R'U2
#      g g
#      w o
# y b o g w r w o
# o y g r w r b b
#      r b
#      y y
#
# Move sequence so far: U R'U'
#      w g
#      o g
# o g w r w o y b
# o y g r w r b b
#      r b
#      y y
#
# Move sequence so far: U2F U
#      y g
#      b o
# g w r g w r w r
# o b y y o b w b
#      r g
#      y o
#
# Move sequence so far: U2F U2
#      b y
#      o g
# r g w r w r g w
# o b y y o b w b
#      r g
#      y o
#
# Move sequence so far: U2F U'
#      o b
#      g y
# w r w r g w r g
# o b y y o b w b
#      r g
#      y o
#
# Move sequence so far: U2F R
#      g w
#      y y
# w r g g o r b r
# o b y o b g o b
#      r w
#      y w
#
# Move sequence so far: U2F R2
#      g g
#      y o
# w r g w b o y r
# o b y w g r w b
#      r o
#      y b
#
# Move sequence so far: U2F R'
#      g w
#      y w
# w r g o g b o r
# o b y b r o g b
#      r w
#      y y
#
# Move sequence so far: U2F2U
#      b g
#      r o
# y g y g w r w r
# o g y w b b w b
#      o r
#      y o
#
# Move sequence so far: U2F2U'
#      o r
#      g b
# w r w r y g y g
# o g y w b b w b
#      o r
#      y o
#
# Move sequence so far: U2F2R
#      g g
#      b w
# w r y r b y r r
# o g y o b g o b
#      o w
#      y w
#
# Move sequence so far: U2F2R2
#      g r
#      b o
# w r y w b b w r
# o g y w g y g b
#      o o
#      y r
#
# Move sequence so far: U2F2R'
#      g w
#      b w
# w r y o g b o r
# o g y r y b r b
#      o g
#      y w
#
# Move sequence so far: U2F'U
#      g g
#      r o
# y y b g w r w o
# o r w g r b w b
#      b y
#      y o
#
# Move sequence so far: U2F'U2
#      r g
#      o g
# b g w r w o y y
# o r w g r b w b
#      b y
#      y o
#
# Move sequence so far: U2F'U'
#      o r
#      g g
# w r w o y y b g
# o r w g r b w b
#      b y
#      y o
#
# Move sequence so far: U2F'R
#      g y
#      g g
# w o y y r b r r
# o r w o b g o b
#      b w
#      y w
#
# Move sequence so far: U2F'R2
#      g y
#      g o
# w o y w b r g r
# o r w w g b y b
#      b o
#      y r
#
# Move sequence so far: U2F'R'
#      g w
#      g w
# w o y o g b o r
# o r w r b r y b
#      b y
#      y g
#
# Move sequence so far: U2R F
#      g y
#      y b
# w r g w r g o r
# o w o b y g o b
#      b r
#      y w
#
# Move sequence so far: U2R F2
#      g y
#      w r
# w b o g y g o r
# o r b w b g o b
#      y r
#      y w
#
# Move sequence so far: U2R F'
#      g y
#      r b
# w y b o w g o r
# o r w g r g o b
#      b y
#      y w
#
# Move sequence so far: U2R U
#      r g
#      y y
# w b r g o r w b
# o y g o b g o b
#      r w
#      y w
#
# Move sequence so far: U2R U2
#      y r
#      y g
# r g o r w b w b
# o y g o b g o b
#      r w
#      y w
#
# Move sequence so far: U2R U'
#      y y
#      g r
# o r w b w b r g
# o y g o b g o b
#      r w
#      y w
#
# Move sequence so far: U2R2F
#      g b
#      y b
# w r g w r r y r
# o o w w o g y b
#      g b
#      y o
#
# Move sequence so far: U2R2F2
#      g b
#      o r
# w g w g y r y r
# o b w w b g y b
#      o r
#      y o
#
# Move sequence so far: U2R2F'
#      g b
#      b g
# w o w w o r y r
# o r w g r g y b
#      b y
#      y o
#
# Move sequence so far: U2R2U
#      r g
#      o b
# w w b r y r w b
# o y g w g g y b
#      r o
#      y o
#
# Move sequence so far: U2R2U2
#      o r
#      b g
# b r y r w b w w
# o y g w g g y b
#      r o
#      y o
#
# Move sequence so far: U2R2U'
#      b o
#      g r
# y r w b w w b r
# o y g w g g y b
#      r o
#      y o
#
# Move sequence so far: U2R'F
#      g w
#      y b
# w r g w r b o r
# o y o o w r b b
#      g g
#      y y
#
# Move sequence so far: U2R'F2
#      g w
#      y r
# w g o g y b o r
# o g o w b r b b
#      w r
#      y y
#
# Move sequence so far: U2R'F'
#      g w
#      g g
# w w o o y b o r
# o r w g r r b b
#      b y
#      y y
#
# Move sequence so far: U2R'U
#      r g
#      w w
# w o g b o r w b
# o y g o g r b b
#      r y
#      y y
#
# Move sequence so far: U2R'U2
#      w r
#      w g
# g b o r w b w o
# o y g o g r b b
#      r y
#      y y
#
# Move sequence so far: U2R'U'
#      w w
#      g r
# o r w b w o g b
# o y g o g r b b
#      r y
#      y y
#
# Move sequence so far: U'F U
#      y r
#      y g
# g g o r w b w r
# o b y g o b w b
#      r w
#      y o
#
# Move sequence so far: U'F U2
#      y y
#      g r
# o r w b w r g g
# o b y g o b w b
#      r w
#      y o
#
# Move sequence so far: U'F U'
#      g y
#      r y
# w b w r g g o r
# o b y g o b w b
#      r w
#      y o
#
# Move sequence so far: U'F R
#      r g
#      y g
# w r g w o o y b
# o b y o b r g b
#      r w
#      y w
#
# Move sequence so far: U'F R2
#      r w
#      y o
# w r g w b o g b
# o b y w r o g b
#      r g
#      y y
#
# Move sequence so far: U'F R'
#      r w
#      y w
# w r g g r b o b
# o b y y o o w b
#      r g
#      y g
#
# Move sequence so far: U'F2U
#      b r
#      r g
# y g y r w b w r
# o w g g y b w b
#      o o
#      y o
#
# Move sequence so far: U'F2U2
#      r b
#      g r
# y r w b w r y g
# o w g g y b w b
#      o o
#      y o
#
# Move sequence so far: U'F2U'
#      g r
#      r b
# w b w r y g y r
# o w g g y b w b
#      o o
#      y o
#
# Move sequence so far: U'F2R
#      r g
#      b g
# w r y o y y r b
# o w g o b r g b
#      o w
#      y w
#
# Move sequence so far: U'F2R2
#      r o
#      b o
# w r y w b y g b
# o w g w r y g b
#      o g
#      y r
#
# Move sequence so far: U'F2R'
#      r w
#      b w
# w r y g r b o b
# o w g r y y o b
#      o g
#      y g
#
# Move sequence so far: U'F'U
#      w r
#      r g
# g y b r w b w o
# o o g g r b w b
#      y y
#      y o
#
# Move sequence so far: U'F'U2
#      r w
#      g r
# b r w b w o g y
# o o g g r b w b
#      y y
#      y o
#
# Move sequence so far: U'F'U'
#      g r
#      r w
# w b w o g y b r
# o o g g r b w b
#      y y
#      y o
#
# Move sequence so far: U'F'R
#      r y
#      w g
# w o g y r b r b
# o o g o b r g b
#      y w
#      y w
#
# Move sequence so far: U'F'R2
#      r y
#      w o
# w o g w b r g b
# o o g w r b y b
#      y g
#      y r
#
# Move sequence so far: U'F'R'
#      r w
#      w w
# w o g g r b o b
# o o g r b r y b
#      y y
#      y g
#
# Move sequence so far: U'R F
#      r g
#      y y
# w r g g o w o b
# o w o b y r g b
#      b r
#      y w
#
# Move sequence so far: U'R F2
#      r g
#      w r
# w b o g y w o b
# o r b g y r g b
#      y o
#      y w
#
# Move sequence so far: U'R F'
#      r g
#      r b
# w y b o w w o b
# o o g g r r g b
#      y y
#      y w
#
# Move sequence so far: U'R U
#      o r
#      y g
# g b r w o b w y
# o y g o b r g b
#      r w
#      y w
#
# Move sequence so far: U'R U2
#      y o
#      g r
# r w o b w y g b
# o y g o b r g b
#      r w
#      y w
#
# Move sequence so far: U'R U'
#      g y
#      r o
# o b w y g b r w
# o y g o b r g b
#      r w
#      y w
#
# Move sequence so far: U'R2F
#      r b
#      y y
# w r g g o r y b
# o g w w o w g b
#      r b
#      y o
#
# Move sequence so far: U'R2F2
#      r b
#      g r
# w r w g y r y b
# o b w g y w g b
#      o o
#      y o
#
# Move sequence so far: U'R2F'
#      r b
#      b r
# w o w w g r y b
# o o g g r w g b
#      y y
#      y o
#
# Move sequence so far: U'R2U
#      o r
#      o b
# g w b r y b w y
# o y g w r w g b
#      r g
#      y o
#
# Move sequence so far: U'R2U2
#      o o
#      b r
# b r y b w y g w
# o y g w r w g b
#      r g
#      y o
#
# Move sequence so far: U'R2U'
#      b o
#      r o
# y b w y g w b r
# o y g w r w g b
#      r g
#      y o
#
# Move sequence so far: U'R'F
#      r w
#      y y
# w r g g o b o b
# o g o g w r b b
#      w r
#      y y
#
# Move sequence so far: U'R'F2
#      r w
#      g r
# w w o g y b o b
# o r g g y r b b
#      w o
#      y y
#
# Move sequence so far: U'R'F'
#      r w
#      r w
# w w g o g b o b
# o o g g r r b b
#      y y
#      y y
#
# Move sequence so far: U'R'U
#      o r
#      w w
# g g r b o b w y
# o y g o w r b b
#      r g
#      y y
#
# Move sequence so far: U'R'U2
#      w o
#      w r
# r b o b w y g g
# o y g o w r b b
#      r g
#      y y
#
# Move sequence so far: U'R'U'
#      w w
#      r o
# o b w y g g r b
# o y g o w r b b
#      r g
#      y y
#
# Move sequence so far: R F U
#      y o
#      g r
# g w o w g y g r
# o w o b y b r b
#      b r
#      y w
#
# Move sequence so far: R F U2
#      g y
#      r o
# o w g y g r g w
# o w o b y b r b
#      b r
#      y w
#
# Move sequence so far: R F U'
#      r g
#      o y
# g y g r g w o w
# o w o b y b r b
#      b r
#      y w
#
# Move sequence so far: R F R
#      o w
#      y b
# g r g r y o g y
# o w o w b w r b
#      b r
#      y g
#
# Move sequence so far: R F R2
#      o r
#      y w
# g r g r b y b y
# o w o g w o w b
#      b r
#      y g
#
# Move sequence so far: R F R'
#      o r
#      y g
# g r g r w b w y
# o w o g o y r b
#      b w
#      y b
#
# Move sequence so far: R F2U
#      w o
#      r r
# o g y w g y g b
# o r b w g b r b
#      y o
#      y w
#
# Move sequence so far: R F2U2
#      r w
#      r o
# y w g y g b o g
# o r b w g b r b
#      y o
#      y w
#
# Move sequence so far: R F2U'
#      r r
#      o w
# g y g b o g y w
# o r b w g b r b
#      y o
#      y w
#
# Move sequence so far: R F2R
#      o g
#      w w
# g b o o g y r y
# o r b w b w r b
#      y r
#      y g
#
# Move sequence so far: R F2R2
#      o o
#      w w
# g b o r b g w y
# o r b g w y g b
#      y r
#      y r
#
# Move sequence so far: R F2R'
#      o r
#      w g
# g b o r w b w y
# o r b r y g o b
#      y g
#      y w
#
# Move sequence so far: R F'U
#      r o
#      b r
# b o w w g y g y
# o o w g r b r b
#      g y
#      y w
#
# Move sequence so far: R F'U2
#      b r
#      r o
# w w g y g y b o
# o o w g r b r b
#      g y
#      y w
#
# Move sequence so far: R F'U'
#      r b
#      o r
# g y g y b o w w
# o o w g r b r b
#      g y
#      y w
#
# Move sequence so far: R F'R
#      o o
#      r g
# g y b y r w b y
# o o w w b w r b
#      g r
#      y g
#
# Move sequence so far: R F'R2
#      o y
#      r w
# g y b r b r g y
# o o w g w w o b
#      g r
#      y b
#
# Move sequence so far: R F'R'
#      o r
#      r g
# g y b r w b w y
# o o w b w r y b
#      g o
#      y g
#
# Move sequence so far: R U F
#      o o
#      y b
# w r g r y y g g
# o w o w r b r b
#      b g
#      y w
#
# Move sequence so far: R U F2
#      o o
#      w r
# w b o g y y g g
# o g w r b b r b
#      r y
#      y w
#
# Move sequence so far: R U F'
#      o o
#      g b
# w r w o w y g g
# o y r g r b r b
#      b y
#      y w
#
# Move sequence so far: R U R
#      o w
#      y o
# w b r w b g r g
# o y g w b y o b
#      r r
#      y g
#
# Move sequence so far: R U R2
#      o w
#      y w
# w b r r b b o g
# o y g g y g w b
#      r o
#      y r
#
# Move sequence so far: R U R'
#      o r
#      y g
# w b r o y b w g
# o y g r g b w b
#      r w
#      y o
#
# Move sequence so far: R U2F
#      y o
#      y w
# r r g g r g w b
# o w o y o b r b
#      b g
#      y w
#
# Move sequence so far: R U2F2
#      y o
#      w r
# r b o g y g w b
# o g y g w b r b
#      o r
#      y w
#
# Move sequence so far: R U2F'
#      y o
#      g b
# r o y o w g w b
# o r g g r b r b
#      w y
#      y w
#
# Move sequence so far: R U2R
#      y y
#      r o
# r w g w b g o b
# o y g w b g o b
#      r r
#      y w
#
# Move sequence so far: R U2R2
#      y w
#      r w
# r w g r b b o b
# o y g w g g y b
#      r o
#      y o
#
# Move sequence so far: R U2R'
#      y r
#      r w
# r w g o g b w b
# o y g o g b w b
#      r y
#      y o
#
# Move sequence so far: R U'F
#      r y
#      y y
# g r g g o b r w
# o w o g o b r b
#      b w
#      y w
#
# Move sequence so far: R U'F2
#      r y
#      w r
# g b o g y b r w
# o w g g y b r b
#      o o
#      y w
#
# Move sequence so far: R U'F'
#      r y
#      w b
# g o g o w b r w
# o o g g r b r b
#      y y
#      y w
#
# Move sequence so far: R U'R
#      r g
#      o o
# g y g w b w o w
# o y g w b b y b
#      r r
#      y r
#
# Move sequence so far: R U'R2
#      r w
#      o w
# g y g r b b o w
# o y g r b w g b
#      r y
#      y o
#
# Move sequence so far: R U'R'
#      r r
#      o r
# g y g y b b w w
# o y g o w b w b
#      r g
#      y o
#
# Move sequence so far: R2F U
#      y o
#      g b
# g w o r y y g r
# o r w w o w r b
#      b b
#      y g
#
# Move sequence so far: R2F U2
#      g y
#      b o
# o r y y g r g w
# o r w w o w r b
#      b b
#      y g
#
# Move sequence so far: R2F U'
#      b g
#      o y
# y y g r g w o r
# o r w w o w r b
#      b b
#      y g
#
# Move sequence so far: R2F R
#      o w
#      y w
# g r g b o o g y
# o r w g w r b b
#      b r
#      y y
#
# Move sequence so far: R2F R2
#      o b
#      y g
# g r g r w o w y
# o r w y r o w b
#      b b
#      y g
#
# Move sequence so far: R2F R'
#      o r
#      y y
# g r g b r w g y
# o r w g o o b b
#      b w
#      y w
#
# Move sequence so far: R2F2U
#      r o
#      r b
# w g y r y y g b
# o b w w g w r b
#      o o
#      y g
#
# Move sequence so far: R2F2U2
#      r r
#      b o
# y r y y g b w g
# o b w w g w r b
#      o o
#      y g
#
# Move sequence so far: R2F2U'
#      b r
#      o r
# y y g b w g y r
# o b w w g w r b
#      o o
#      y g
#
# Move sequence so far: R2F2R
#      o g
#      r w
# g b w o g y r y
# o b w g w r b b
#      o r
#      y y
#
# Move sequence so far: R2F2R'
#      o r
#      r y
# g b w b r w g y
# o b w r y g o b
#      o g
#      y w
#
# Move sequence so far: R2F'U
#      b o
#      b b
# w w r r y y g o
# o o w g r w r b
#      g y
#      y g
#
# Move sequence so far: R2F'U2
#      b b
#      b o
# r r y y g o w w
# o o w g r w r b
#      g y
#      y g
#
# Move sequence so far: R2F'U'
#      b b
#      o b
# y y g o w w r r
# o o w g r w r b
#      g y
#      y g
#
# Move sequence so far: R2F'R
#      o w
#      b g
# g o w y r r b y
# o o w g w r b b
#      g r
#      y y
#
# Move sequence so far: R2F'R2
#      o y
#      b g
# g o w r w r g y
# o o w y r r w b
#      g b
#      y b
#
# Move sequence so far: R2F'R'
#      o r
#      b y
# g o w b r w g y
# o o w b r r y b
#      g w
#      y g
#
# Move sequence so far: R2U F
#      o o
#      y w
# w r g b o y g g
# o r w r b w r b
#      b y
#      y g
#
# Move sequence so far: R2U F2
#      o o
#      r r
# w b w g y y g g
# o y r b w w r b
#      b o
#      y g
#
# Move sequence so far: R2U F'
#      o o
#      y b
# w b r w r y g g
# o o b g r w r b
#      w y
#      y g
#
# Move sequence so far: R2U R
#      o r
#      o w
# w w b r b y b g
# o y g g w y o b
#      r r
#      y g
#
# Move sequence so far: R2U R2
#      o r
#      o g
# w w b r w b w g
# o y g g y y r b
#      r o
#      y b
#
# Move sequence so far: R2U R'
#      o r
#      o g
# w w b o y w g g
# o y g b y b r b
#      r r
#      y w
#
# Move sequence so far: R2U2F
#      o o
#      y r
# b r g y b g w w
# o r w y o w r b
#      b g
#      y g
#
# Move sequence so far: R2U2F2
#      o o
#      r r
# b b w g y g w w
# o g y y r w r b
#      o b
#      y g
#
# Move sequence so far: R2U2F'
#      o o
#      g b
# b o y w r g w w
# o b y g r w r b
#      r y
#      y g
#
# Move sequence so far: R2U2R
#      o y
#      b w
# b r y r b g o w
# o y g g w g o b
#      r r
#      y w
#
# Move sequence so far: R2U2R'
#      o r
#      b w
# b r y o g w g w
# o y g o g b r b
#      r y
#      y w
#
# Move sequence so far: R2U'F
#      b o
#      y y
# y r g g o w b r
# o r w g o w r b
#      b w
#      y g
#
# Move sequence so far: R2U'F2
#      b o
#      r r
# y b w g y w b r
# o w g g y w r b
#      o o
#      y g
#
# Move sequence so far: R2U'F'
#      b o
#      w b
# y o g w r w b r
# o o g g r w r b
#      y y
#      y g
#
# Move sequence so far: R2U'R
#      b g
#      o w
# y y g r b w o r
# o y g g w w o b
#      r r
#      y b
#
# Move sequence so far: R2U'R2
#      b r
#      o g
# y y g r w b w r
# o y g b w w g b
#      r o
#      y o
#
# Move sequence so far: R2U'R'
#      b r
#      o b
# y y g o w w g r
# o y g o w b r b
#      r g
#      y w
#
# Move sequence so far: R'F U
#      y o
#      g w
# g w o b o y g r
# o r g r w r b b
#      w b
#      y y
#
# Move sequence so far: R'F U2
#      g y
#      w o
# o b o y g r g w
# o r g r w r b b
#      w b
#      y y
#
# Move sequence so far: R'F U'
#      w g
#      o y
# o y g r g w o b
# o r g r w r b b
#      w b
#      y y
#
# Move sequence so far: R'F R
#      o w
#      y r
# g r g b w o g y
# o r g y r b w b
#      w b
#      y o
#
# Move sequence so far: R'F R2
#      o b
#      y y
# g r g b r w r y
# o r g o b o w b
#      w w
#      y g
#
# Move sequence so far: R'F R'
#      o b
#      y o
# g r g w b r y y
# o r g g o w b b
#      w w
#      y r
#
# Move sequence so far: R'F2U
#      r o
#      r w
# g g y b o y g w
# o b r w g r b b
#      w o
#      y y
#
# Move sequence so far: R'F2U2
#      r r
#      w o
# y b o y g w g g
# o b r w g r b b
#      w o
#      y y
#
# Move sequence so far: R'F2U'
#      w r
#      o r
# o y g w g g y b
# o b r w g r b b
#      w o
#      y y
#
# Move sequence so far: R'F2R
#      o g
#      r w
# g w g o g y r y
# o b r y r b w b
#      w b
#      y o
#
# Move sequence so far: R'F2R2
#      o o
#      r y
# g w g b r g w y
# o b r o b y g b
#      w w
#      y r
#
# Move sequence so far: R'F2R'
#      o b
#      r o
# g w g w b r y y
# o b r r y g o b
#      w g
#      y w
#
# Move sequence so far: R'F'U
#      b o
#      w w
# r g r b o y g w
# o o w g r r b b
#      g y
#      y y
#
# Move sequence so far: R'F'U2
#      w b
#      w o
# r b o y g w r g
# o o w g r r b b
#      g y
#      y y
#
# Move sequence so far: R'F'U'
#      w w
#      o b
# o y g w r g r b
# o o w g r r b b
#      g y
#      y y
#
# Move sequence so far: R'F'R
#      o g
#      b g
# g w r y r r w y
# o o w y r b w b
#      g b
#      y o
#
# Move sequence so far: R'F'R2
#      o y
#      b y
# g w r b r r g y
# o o w o b r g b
#      g w
#      y w
#
# Move sequence so far: R'F'R'
#      o b
#      b o
# g w r w b r y y
# o o w w r r y b
#      g g
#      y g
#
# Move sequence so far: R'U F
#      o o
#      y r
# w r g b w y g g
# o r g b w r b b
#      w o
#      y y
#
# Move sequence so far: R'U F2
#      o o
#      r r
# w w g g y y g g
# o o b b r r b b
#      w w
#      y y
#
# Move sequence so far: R'U F'
#      o o
#      o w
# w w b g r y g g
# o w b g r r b b
#      r y
#      y y
#
# Move sequence so far: R'U R
#      o b
#      w g
# w r b r w o w g
# o y g y r y o b
#      r b
#      y g
#
# Move sequence so far: R'U R2
#      o r
#      w y
# w r b b r w g g
# o y g g y o b b
#      r o
#      y w
#
# Move sequence so far: R'U R'
#      o b
#      w g
# w r b o y r y g
# o y g w o w r b
#      r b
#      y g
#
# Move sequence so far: R'U2F
#      w o
#      y b
# b r g o w g w r
# o r g y o r b b
#      w g
#      y y
#
# Move sequence so far: R'U2F2
#      w o
#      r r
# b w g g y g w r
# o g y o b r b b
#      o w
#      y y
#
# Move sequence so far: R'U2F'
#      w o
#      g w
# b o y g r g w r
# o w o g r r b b
#      b y
#      y y
#
# Move sequence so far: R'U2R
#      w y
#      w g
# b b o r w g o r
# o y g y r g o b
#      r b
#      y w
#
# Move sequence so far: R'U2R2
#      w r
#      w y
# b b o b r w g r
# o y g w g g y b
#      r o
#      y o
#
# Move sequence so far: R'U2R'
#      w b
#      w w
# b b o o g r y r
# o y g o g w r b
#      r y
#      y g
#
# Move sequence so far: R'U'F
#      w w
#      y y
# o r g g o r b b
# o r g g o r b b
#      w w
#      y y
#
# Move sequence so far: R'U'F2
#      w w
#      r r
# o w g g y r b b
# o w g g y r b b
#      o o
#      y y
#
# Move sequence so far: R'U'F'
#      w w
#      w w
# o o g g r r b b
# o o g g r r b b
#      y y
#      y y
#
# Cube solved!
# Final solution path: R'U'F'
# Number of moves: 3
# Time taken: 38.34 seconds

# %%
import time

SOLVED_PERM = "ggggwwwwrrrrbbbbyyyyoooo"
NOTATIONS = ["F ", "F2", "F'", "U ", "U2", "U'", "R ", "R2", "R'"]

def produce_permutation(notation, perm):
    f1,f2,f3,f4,u1,u2,u3,u4,r1,r2,r3,r4,b1,b2,b3,b4,d1,d2,d3,d4,l1,l2,l3,l4 = perm

    if notation == "F ":
        perm = f3+f1+f4+f2+u1+u2+l4+l2+u3+r2+u4+r4+b1+b2+b3+b4+r3+r1+d3+d4+l1+d1+l3+d2
    elif notation == "F2":
        perm = f4+f3+f2+f1+u1+u2+d2+d1+l4+r2+l2+r4+b1+b2+b3+b4+u4+u3+d3+d4+l1+r3+l3+r1
    elif notation == "F'":
        perm = f2+f4+f1+f3+u1+u2+r1+r3+d2+r2+d1+r4+b1+b2+b3+b4+l2+l4+d3+d4+l1+u4+l3+u3
    elif notation == "U ":
        perm = r1+r2+f3+f4+u3+u1+u4+u2+b1+b2+r3+r4+l1+l2+b3+b4+d1+d2+d3+d4+f1+f2+l3+l4
    elif notation == "U2":
        perm = b1+b2+f3+f4+u4+u3+u2+u1+l1+l2+r3+r4+f1+f2+b3+b4+d1+d2+d3+d4+r1+r2+l3+l4
    elif notation == "U'":
        perm = l1+l2+f3+f4+u2+u4+u1+u3+f1+f2+r3+r4+r1+r2+b3+b4+d1+d2+d3+d4+b1+b2+l3+l4
    elif notation == "R ":
        perm = f1+d2+f3+d4+u1+f2+u3+f4+r3+r1+r4+r2+u4+b2+u2+b4+d1+b3+d3+b1+l1+l2+l3+l4
    elif notation == "R2":
        perm = f1+b3+f3+b1+u1+d2+u3+d4+r4+r3+r2+r1+f4+b2+f2+b4+d1+u2+d3+u4+l1+l2+l3+l4
    elif notation == "R'":
        perm = f1+u2+f3+u4+u1+b3+u3+b1+r2+r4+r1+r3+d4+b2+d2+b4+d1+f2+d3+f4+l1+l2+l3+l4
    else:
        perm = perm
    return perm

def heuristic(perm):
    """Estimate how far perm is from solved."""
    faces = [perm[i:i+4] for i in range(0, 24, 4)]
    count = 0
    for face in faces:
        max_count = max(face.count(face[i]) for i in range(4))
        count += 4 - max_count
    return count

def ida_star(start_perm, max_depth=14):
    bound = heuristic(start_perm)
    path = []
    visited = set()

    def search(perm, g, prev_face):
        f = g + heuristic(perm)
        if f > bound:
            return f
        if perm == SOLVED_PERM:
            return "FOUND"

        print("Visited state (g =", g, ", heuristic =", heuristic(perm), "):")
        print_cube(perm)
        time.sleep(0.1)

        min_t = float('inf')
        for move in NOTATIONS:
            if prev_face and prev_face == move[0]:
                continue
            next_perm = produce_permutation(move, perm)
            if next_perm in visited:
                continue
            visited.add(next_perm)
            path.append(move)
            t = search(next_perm, g + 1, move[0])
            if t == "FOUND":
                return "FOUND"
            if t < min_t:
                min_t = t
            path.pop()
            visited.remove(next_perm)
        return min_t

    while True:
        visited.clear()
        visited.add(start_perm)
        t = search(start_perm, 0, None)
        if t == "FOUND":
            return path
        if t == float('inf') or len(path) > max_depth:
            return None
        bound = t

def print_cube(perm):
    faces = {
        "F": perm[0:4],
        "U": perm[4:8],
        "R": perm[8:12],
        "B": perm[12:16],
        "D": perm[16:20],
        "L": perm[20:24],
    }
    print("    ", faces["U"][0], faces["U"][1])
    print("    ", faces["U"][2], faces["U"][3])
    print(faces["L"][0], faces["L"][1], faces["F"][0], faces["F"][1], faces["R"][0], faces["R"][1], faces["B"][0], faces["B"][1])
    print(faces["L"][2], faces["L"][3], faces["F"][2], faces["F"][3], faces["R"][2], faces["R"][3], faces["B"][2], faces["B"][3])
    print("    ", faces["D"][0], faces["D"][1])
    print("    ", faces["D"][2], faces["D"][3])
    print()

# --------------------------------
# Example scramble
scrambled_perm = SOLVED_PERM
scrambled_perm = produce_permutation("F ", scrambled_perm)
scrambled_perm = produce_permutation("U ", scrambled_perm)
scrambled_perm = produce_permutation("R ", scrambled_perm)

print("Scrambled cube:")
print_cube(scrambled_perm)

start_time = time.time()
solution_moves = ida_star(scrambled_perm)
end_time = time.time()

if solution_moves:
    print("✅ Solution path:", " ".join(solution_moves))
    print("✅ Number of moves:", len(solution_moves))
    print(f"✅ Time taken: {end_time - start_time:.2f} seconds")
else:
    print("❌ No solution found.")
# Out:
# Scrambled cube:
#      o r
#      o g
# g g w r w b w y
# o y g y r b w b
#      r b
#      y o
#
# Visited state (g = 0 , heuristic = 14 ):
#      o r
#      o g
# g g w r w b w y
# o y g y r b w b
#      r b
#      y o
#
# Visited state (g = 1 , heuristic = 12 ):
#      o r
#      w r
# g g r y b b w y
# o o w g r b w b
#      g y
#      y o
#
# Visited state (g = 2 , heuristic = 10 ):
#      r r
#      o w
# w y g g r y b b
# o o w g r b w b
#      g y
#      y o
#
# Visited state (g = 3 , heuristic = 10 ):
#      r r
#      y g
# w r g w o y b b
# o r g g y b w b
#      w o
#      y o
#
# Visited state (g = 3 , heuristic = 8 ):
#      r r
#      r r
# w w g g y y b b
# o o g w g b w b
#      y o
#      y o
#
# Visited state (g = 4 , heuristic = 8 ):
#      r r
#      r r
# g g y y b b w w
# o o g w g b w b
#      y o
#      y o
#
# Visited state (g = 4 , heuristic = 10 ):
#      r r
#      r r
# y y b b w w g g
# o o g w g b w b
#      y o
#      y o
#
# Visited state (g = 4 , heuristic = 8 ):
#      r r
#      r r
# b b w w g g y y
# o o g w g b w b
#      y o
#      y o
#
# Visited state (g = 2 , heuristic = 10 ):
#      o y
#      w o
# g g r w b r g y
# o o w w b b y b
#      g r
#      y r
#
# Visited state (g = 2 , heuristic = 9 ):
#      o w
#      w w
# g g r r b b o y
# o o w r b r y b
#      g y
#      y g
#
# Visited state (g = 3 , heuristic = 11 ):
#      o w
#      o g
# g g w r w b o y
# o y r r w r y b
#      b b
#      y g
#
# Visited state (g = 3 , heuristic = 8 ):
#      w w
#      o w
# o y g g r r b b
# o o w r b r y b
#      g y
#      y g
#
# Visited state (g = 4 , heuristic = 10 ):
#      w w
#      r b
# o w g r y r b b
# o o g w g r y b
#      y o
#      y g
#
# Visited state (g = 5 , heuristic = 8 ):
#      w r
#      r w
# o w g o g y b b
# o o g g r r w b
#      y y
#      y b
#
# Visited state (g = 4 , heuristic = 10 ):
#      w y
#      o b
# o y g w r r g b
# o o w w r b y b
#      g g
#      y r
#
# Visited state (g = 1 , heuristic = 12 ):
#      r g
#      o o
# w y g g w r w b
# o y g y r b w b
#      r b
#      y o
#
# Visited state (g = 2 , heuristic = 10 ):
#      r g
#      b r
# w r y g y r w b
# o w g g y b w b
#      o o
#      y o
#
# Visited state (g = 2 , heuristic = 9 ):
#      r g
#      w r
# w o g y b r w b
# o o g g r b w b
#      y y
#      y o
#
# Visited state (g = 3 , heuristic = 11 ):
#      w r
#      r g
# g y b r w b w o
# o o g g r b w b
#      y y
#      y o
#
# Visited state (g = 3 , heuristic = 8 ):
#      r w
#      w w
# w o g g r b o b
# o o g r b r y b
#      y y
#      y g
#
# Visited state (g = 4 , heuristic = 10 ):
#      r w
#      r b
# w w g r y b o b
# o w g g y r y b
#      o o
#      y g
#
# Visited state (g = 5 , heuristic = 8 ):
#      r r
#      r g
# w w g o y y b b
# o w g g r b w b
#      o y
#      y o
#
# Visited state (g = 4 , heuristic = 10 ):
#      w w
#      r w
# o b w o g g r b
# o o g r b r y b
#      y y
#      y g
#
# Visited state (g = 2 , heuristic = 10 ):
#      r w
#      o w
# w y g g r b o b
# o y g o w r b b
#      r g
#      y y
#
# Visited state (g = 3 , heuristic = 10 ):
#      r w
#      g r
# w w o g y b o b
# o r g g y r b b
#      w o
#      y y
#
# Visited state (g = 3 , heuristic = 8 ):
#      r w
#      r w
# w w g o g b o b
# o o g g r r b b
#      y y
#      y y
#
# Visited state (g = 4 , heuristic = 8 ):
#      r r
#      w w
# g o g b o b w w
# o o g g r r b b
#      y y
#      y y
#
# Visited state (g = 4 , heuristic = 10 ):
#      w r
#      w r
# g b o b w w g o
# o o g g r r b b
#      y y
#      y y
#
# Visited state (g = 4 , heuristic = 8 ):
#      w w
#      r r
# o b w w g o g b
# o o g g r r b b
#      y y
#      y y
#
# Visited state (g = 1 , heuristic = 10 ):
#      o b
#      o o
# g g w w b r y y
# o y g w b w r b
#      r r
#      y g
#
# Visited state (g = 2 , heuristic = 12 ):
#      o b
#      y g
# g r g w o r y y
# o r w w o w r b
#      b b
#      y g
#
# Visited state (g = 2 , heuristic = 12 ):
#      o b
#      r r
# g b w g y r y y
# o b w w g w r b
#      o o
#      y g
#
# Visited state (g = 2 , heuristic = 8 ):
#      o b
#      b b
# g o w w r r y y
# o o w g r w r b
#      g y
#      y g
#
# Visited state (g = 3 , heuristic = 9 ):
#      b b
#      o b
# y y g o w w r r
# o o w g r w r b
#      g y
#      y g
#
# Visited state (g = 4 , heuristic = 10 ):
#      b o
#      o g
# y y g y r w b r
# o o w g w w b b
#      g r
#      y r
#
# Visited state (g = 3 , heuristic = 10 ):
#      o w
#      b g
# g o w y r r b y
# o o w g w r b b
#      g r
#      y y
#
# Visited state (g = 4 , heuristic = 10 ):
#      o w
#      o o
# g g w w b r b y
# o r g y g r b b
#      w r
#      y y
#
# Visited state (g = 4 , heuristic = 10 ):
#      o w
#      r w
# g g y g r r b y
# o b w w g r b b
#      o o
#      y y
#
# Visited state (g = 3 , heuristic = 11 ):
#      o r
#      b y
# g o w b r w g y
# o o w b r r y b
#      g w
#      y g
#
# Visited state (g = 2 , heuristic = 12 ):
#      o o
#      o b
# w w b r y y g g
# o y g w b w r b
#      r r
#      y g
#
# Visited state (g = 2 , heuristic = 12 ):
#      o o
#      b o
# b r y y g g w w
# o y g w b w r b
#      r r
#      y g
#
# Visited state (g = 2 , heuristic = 8 ):
#      b o
#      o o
# y y g g w w b r
# o y g w b w r b
#      r r
#      y g
#
# Visited state (g = 3 , heuristic = 9 ):
#      b o
#      w b
# y o g w r w b r
# o o g g r w r b
#      y y
#      y g
#
# Visited state (g = 4 , heuristic = 10 ):
#      b w
#      w g
# y o g y r r b r
# o o g g w w o b
#      y r
#      y b
#
# Visited state (g = 3 , heuristic = 10 ):
#      b g
#      o w
# y y g r b w o r
# o y g g w w o b
#      r r
#      y b
#
# Visited state (g = 4 , heuristic = 10 ):
#      b g
#      y y
# y r g g o w o r
# o r g r w w o b
#      w b
#      y b
#
# Visited state (g = 4 , heuristic = 10 ):
#      b g
#      b w
# y w r g r w o r
# o o g g r w o b
#      y y
#      y b
#
# Visited state (g = 3 , heuristic = 11 ):
#      b r
#      o b
# y y g o w w g r
# o y g o w b r b
#      r g
#      y w
#
# Visited state (g = 1 , heuristic = 12 ):
#      o w
#      o w
# g g w r b b o y
# o y g g w r b b
#      r r
#      y y
#
# Visited state (g = 2 , heuristic = 10 ):
#      o w
#      b w
# g w r g r b o y
# o o w g r r b b
#      g y
#      y y
#
# Visited state (g = 3 , heuristic = 8 ):
#      w w
#      o b
# o y g w r g r b
# o o w g r r b b
#      g y
#      y y
#
# Visited state (g = 4 , heuristic = 9 ):
#      w w
#      r r
# o b w g y g r b
# o o g w g r b b
#      y o
#      y y
#
# Visited state (g = 4 , heuristic = 10 ):
#      w w
#      o g
# o y g y r r b b
# o o w y r g w b
#      g b
#      y r
#
# Visited state (g = 3 , heuristic = 8 ):
#      o b
#      b o
# g w r w b r y y
# o o w w r r y b
#      g g
#      y g
#
# Visited state (g = 4 , heuristic = 10 ):
#      o b
#      o w
# g g w r b r y y
# o g w w o r y b
#      r b
#      y g
#
# Visited state (g = 4 , heuristic = 9 ):
#      b o
#      o b
# y y g w r w b r
# o o w w r r y b
#      g g
#      y g
#
# Visited state (g = 2 , heuristic = 12 ):
#      w o
#      w o
# b b o y g g w r
# o y g g w r b b
#      r r
#      y y
#
# Visited state (g = 3 , heuristic = 10 ):
#      w o
#      g w
# b o y g r g w r
# o w o g r r b b
#      b y
#      y y
#
# Visited state (g = 4 , heuristic = 10 ):
#      g w
#      w o
# y g r g w r b o
# o w o g r r b b
#      b y
#      y y
#
# Visited state (g = 4 , heuristic = 10 ):
#      w g
#      g g
# b o y y r r w r
# o w o y r g o b
#      b b
#      y w
#
# Visited state (g = 3 , heuristic = 10 ):
#      w b
#      w w
# b b o o g r y r
# o y g o g w r b
#      r y
#      y g
#
# Visited state (g = 4 , heuristic = 10 ):
#      w b
#      y b
# b r g o w r y r
# o y o o w w r b
#      g g
#      y g
#
# Visited state (g = 4 , heuristic = 10 ):
#      w w
#      w b
# o o g r y r b b
# o y g o g w r b
#      r y
#      y g
#
# Visited state (g = 2 , heuristic = 8 ):
#      w w
#      o o
# o y g g w r b b
# o y g g w r b b
#      r r
#      y y
#
# Visited state (g = 3 , heuristic = 8 ):
#      w w
#      y y
# o r g g o r b b
# o r g g o r b b
#      w w
#      y y
#
# Visited state (g = 3 , heuristic = 8 ):
#      w w
#      r r
# o w g g y r b b
# o w g g y r b b
#      o o
#      y y
#
# ✅ Solution path: R' U' F'
# ✅ Number of moves: 3
# ✅ Time taken: 6.64 seconds

# %%
import time
from collections import deque

# Solved permutation string
SOLVED_PERM = "ggggwwwwrrrrbbbbyyyyoooo"

# Notations
NOTATIONS = ["F ", "F2", "F'", "U ", "U2", "U'", "R ", "R2", "R'"]

def split_faces(perm):
    return {
        "F": perm[0:4],
        "U": perm[4:8],
        "R": perm[8:12],
        "B": perm[12:16],
        "D": perm[16:20],
        "L": perm[20:24],
    }

def print_cube(perm):
    faces = split_faces(perm)
    print("    ", faces["U"][0], faces["U"][1])
    print("    ", faces["U"][2], faces["U"][3])
    print(faces["L"][0], faces["L"][1], faces["F"][0], faces["F"][1], faces["R"][0], faces["R"][1], faces["B"][0], faces["B"][1])
    print(faces["L"][2], faces["L"][3], faces["F"][2], faces["F"][3], faces["R"][2], faces["R"][3], faces["B"][2], faces["B"][3])
    print("    ", faces["D"][0], faces["D"][1])
    print("    ", faces["D"][2], faces["D"][3])
    print()

def produce_permutation(notation, perm):
    f1,f2,f3,f4,u1,u2,u3,u4,r1,r2,r3,r4,b1,b2,b3,b4,d1,d2,d3,d4,l1,l2,l3,l4 = perm

    if notation == "F ":
        perm = f3+f1+f4+f2+u1+u2+l4+l2+u3+r2+u4+r4+b1+b2+b3+b4+r3+r1+d3+d4+l1+d1+l3+d2
    elif notation == "F2":
        perm = f4+f3+f2+f1+u1+u2+d2+d1+l4+r2+l2+r4+b1+b2+b3+b4+u4+u3+d3+d4+l1+r3+l3+r1
    elif notation == "F'":
        perm = f2+f4+f1+f3+u1+u2+r1+r3+d2+r2+d1+r4+b1+b2+b3+b4+l2+l4+d3+d4+l1+u4+l3+u3
    elif notation == "U ":
        perm = r1+r2+f3+f4+u3+u1+u4+u2+b1+b2+r3+r4+l1+l2+b3+b4+d1+d2+d3+d4+f1+f2+l3+l4
    elif notation == "U2":
        perm = b1+b2+f3+f4+u4+u3+u2+u1+l1+l2+r3+r4+f1+f2+b3+b4+d1+d2+d3+d4+r1+r2+l3+l4
    elif notation == "U'":
        perm = l1+l2+f3+f4+u2+u4+u1+u3+f1+f2+r3+r4+r1+r2+b3+b4+d1+d2+d3+d4+b1+b2+l3+l4
    elif notation == "R ":
        perm = f1+d2+f3+d4+u1+f2+u3+f4+r3+r1+r4+r2+u4+b2+u2+b4+d1+b3+d3+b1+l1+l2+l3+l4
    elif notation == "R2":
        perm = f1+b3+f3+b1+u1+d2+u3+d4+r4+r3+r2+r1+f4+b2+f2+b4+d1+u2+d3+u4+l1+l2+l3+l4
    elif notation == "R'":
        perm = f1+u2+f3+u4+u1+b3+u3+b1+r2+r4+r1+r3+d4+b2+d2+b4+d1+f2+d3+f4+l1+l2+l3+l4
    else:
        perm = perm
    return perm

def is_solved(perm):
    for i in range(0, 24, 4):
        if perm[i:i+4] != perm[i]*4:
            return False
    return True

def bfs_bidirectional(start_perm):
    if is_solved(start_perm):
        return ""

    queue_fwd = deque()
    queue_bwd = deque()

    visited_fwd = {start_perm: ""}
    visited_bwd = {SOLVED_PERM: ""}

    queue_fwd.append(start_perm)
    queue_bwd.append(SOLVED_PERM)

    while queue_fwd and queue_bwd:
        # Expand from forward side
        for _ in range(len(queue_fwd)):
            perm = queue_fwd.popleft()
            path = visited_fwd[perm]

            print(f"Forward path so far: {path}")
            print_cube(perm)
            time.sleep(0.1)

            for notation in NOTATIONS:
                if len(path) >= 2 and path[-2] == notation[0]:
                    continue

                new_perm = produce_permutation(notation, perm)
                if new_perm in visited_fwd:
                    continue

                visited_fwd[new_perm] = path + notation
                if new_perm in visited_bwd:
                    # Path found!
                    return visited_fwd[new_perm] + reverse_path(visited_bwd[new_perm])
                queue_fwd.append(new_perm)

        # Expand from backward side
        for _ in range(len(queue_bwd)):
            perm = queue_bwd.popleft()
            path = visited_bwd[perm]

            print(f"Backward path so far: {path}")
            print_cube(perm)
            time.sleep(0.2)

            for notation in NOTATIONS:
                if len(path) >= 2 and path[-2] == notation[0]:
                    continue

                new_perm = produce_permutation(notation, perm)
                if new_perm in visited_bwd:
                    continue

                visited_bwd[new_perm] = path + notation
                if new_perm in visited_fwd:
                    # Path found!
                    return visited_fwd[new_perm] + reverse_path(visited_bwd[new_perm])
                queue_bwd.append(new_perm)

    return None

def reverse_notation(notation):
    if notation == "F ":
        return "F'"
    elif notation == "F'":
        return "F "
    elif notation == "U ":
        return "U'"
    elif notation == "U'":
        return "U "
    elif notation == "R ":
        return "R'"
    elif notation == "R'":
        return "R "
    else:
        return notation  # F2, U2, R2 remain same

def reverse_path(path):
    moves = [path[i:i+2] for i in range(0, len(path), 2)]
    reversed_moves = [reverse_notation(m) for m in reversed(moves)]
    return "".join(reversed_moves)

# -------------------------------------
# Example scramble
scrambled_perm = SOLVED_PERM
scrambled_perm = produce_permutation("F ", scrambled_perm)
scrambled_perm = produce_permutation("U ", scrambled_perm)
scrambled_perm = produce_permutation("R ", scrambled_perm)

print("Scrambled state:")
print_cube(scrambled_perm)

start_time = time.time()

solution_path = bfs_bidirectional(scrambled_perm)

end_time = time.time()

if solution_path:
    print("✅ Final solution path to follow:", solution_path)
    print("✅ Number of moves:", len(solution_path) // 2)
    print(f"✅ Time taken: {end_time - start_time:.2f} seconds")
else:
    print("❌ No solution found!")
# Out:
# Scrambled state:
#      o r
#      o g
# g g w r w b w y
# o y g y r b w b
#      r b
#      y o
#
# Forward path so far:
#      o r
#      o g
# g g w r w b w y
# o y g y r b w b
#      r b
#      y o
#
# Backward path so far:
#      w w
#      w w
# o o g g r r b b
# o o g g r r b b
#      y y
#      y y
#
# Forward path so far: F
#      o r
#      y g
# g r g w o b w y
# o b y r g b w b
#      r w
#      y o
#
# Forward path so far: F2
#      o r
#      b r
# g r y g y b w y
# o w r w g b w b
#      g o
#      y o
#
# Forward path so far: F'
#      o r
#      w r
# g g r y b b w y
# o o w g r b w b
#      g y
#      y o
#
# Forward path so far: U
#      o o
#      g r
# w r w b w y g g
# o y g y r b w b
#      r b
#      y o
#
# Forward path so far: U2
#      g o
#      r o
# w b w y g g w r
# o y g y r b w b
#      r b
#      y o
#
# Forward path so far: U'
#      r g
#      o o
# w y g g w r w b
# o y g y r b w b
#      r b
#      y o
#
# Forward path so far: R
#      o r
#      o y
# g g w b r w g y
# o y g o b b r b
#      r w
#      y w
#
# Forward path so far: R2
#      o b
#      o o
# g g w w b r y y
# o y g w b w r b
#      r r
#      y g
#
# Forward path so far: R'
#      o w
#      o w
# g g w r b b o y
# o y g g w r b b
#      r r
#      y y
#
# ✅ Final solution path to follow: R'U'F'
# ✅ Number of moves: 3
# ✅ Time taken: 1.20 seconds
